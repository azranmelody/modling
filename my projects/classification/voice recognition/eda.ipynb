# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sns.set_style('darkgrid')

# %%
#from melo_viz import basic_viz as bv

# %%
# %run ../../../visualizations/vizual_from_basis1.ipynb

# %%
pwd
# Out:
# 'C:\\Users\\Melody\\Desktop\\Melody\\self learning\\modling\\my projects\\classification\\voice recognition'

# %%
df = pd.read_csv('dataset/voice.csv')

# %%
labels = {'male' : 1 , 'female' : 2}
df['label'] = df['label'].map(labels)

# %%
df['IQR_BIN'] = pd.qcut(df['IQR'] , 4 , range(4))

# %%
df['grouping'] = np.where(df['kurt']>500 , 'A' , (np.where(df['kurt'] <10 , 'C' , 'B')))

# %%
df['grouping'].value_counts()
# Out:
# C    1905
# B    1179
# A      84
# Name: grouping, dtype: int64

# %%
#plt.figure(figsize=(2,10))
#sns.heatmap(pd.DataFrame(abs(df.corr()['label'])) ,annot=True , vmin=0.4)

# %%
#sns.boxplot(data=df ,x=df['IQR_BIN'], y=df['meanfun'], hue ='label')

# %%
df_p = df.pivot_table(index='IQR_BIN', columns='label',values='meanfun', aggfunc='count')

# %%
df_p
# Out:
# label      1    2
# IQR_BIN
# 0         10  782
# 1        210  582
# 2        761   31
# 3        603  189

# %%
fig, ax = plt.subplots()

# %%
ax = df_p.plot( kind='bar', stacked=True)

# %%
kamut_per_feature(df,x_axis='grouping',with_pie_aside=True, figsize=(10,4) ,palette='Set3',order_by_count=True)

# %%
kamut_per_feature1_by_feature2(df,'label',x_axis='grouping', font_scale=2.5 , palette='husl',order_by_count=True)

# %%
ahuz_per_feature1_by_feature2(df,'label',x_axis='IQR_BIN', font_scale=2.5 , count_what='sd',order_by_count=None)
# Out:
# [0.9873737373737373, 0.7348484848484849, 0.039141414141414144, 0.23863636363636365]

# %%
# %run ../../../visualizations/vizual_from_basis1.ipynb

# %%
ahuz_and_kamut_per_feature1_by_feature2(df,'label',x_axis='IQR_BIN', font_scale=1.8 , count_what='sd', side_by_side=True , order_by_count=True)

# %%
pie_amount_by_feature(df,'IQR_BIN')
