# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# %run ../../../../visualizations/vizual_from_basis1.ipynb

# %%
data = pd.read_csv('../DATA/Surgical-deepnet.csv')

# %%
data['month'] = data['month'].astype(int)

# %%
data.head()
# Out:
#      bmi   Age  asa_status  baseline_cancer  baseline_charlson  baseline_cvd  \
# 0  19.31  59.2           1                1                  0             0
# 1  18.73  59.1           0                0                  0             0
# 2  21.85  59.0           0                0                  0             0
# 3  18.49  59.0           1                0                  1             0
# 4  19.70  59.0           1                0                  0             0
#
#    baseline_dementia  baseline_diabetes  baseline_digestive  \
# 0                  0                  0                   0
# 1                  0                  0                   0
# 2                  0                  0                   0
# 3                  0                  1                   1
# 4                  0                  0                   0
#
#    baseline_osteoart      ...       complication_rsi  dow  gender   hour  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14635 entries, 0 to 14634
# Data columns (total 25 columns):
# bmi                    14635 non-null float64
# Age                    14635 non-null float64
# asa_status             14635 non-null int64
# baseline_cancer        14635 non-null int64
# baseline_charlson      14635 non-null int64
# baseline_cvd           14635 non-null int64
# baseline_dementia      14635 non-null int64
# baseline_diabetes      14635 non-null int64
# baseline_digestive     14635 non-null int64
# baseline_osteoart      14635 non-null int64
# baseline_psych         14635 non-null int64
# baseline_pulmonary     14635 non-null int64
# ahrq_ccs               14635 non-null int64
# ccsComplicationRate    14635 non-null float64
# ccsMort30Rate          14635 non-null float64
# complication_rsi       14635 non-null float64
# dow                    14635 non-null int64
# gender                 14635 non-null int64
# ...

# %%
data.describe()
# Out:
#                 bmi           Age    asa_status  baseline_cancer  \
# count  14635.000000  14635.000000  14635.000000     14635.000000
# mean      31.295642     63.205268      0.632320         0.262316
# std        8.152709     18.088191      0.539952         0.439909
# min        2.150000      6.100000      0.000000         0.000000
# 25%       26.510000     51.500000      0.000000         0.000000
# 50%       28.980000     59.700000      1.000000         0.000000
# 75%       35.295000     74.700000      1.000000         1.000000
# max       92.590000     90.000000      2.000000         1.000000
#
#        baseline_charlson  baseline_cvd  baseline_dementia  baseline_diabetes  \
# count       14635.000000  14635.000000       14635.000000       14635.000000
# mean            0.977520      0.620294           0.004851           0.120875
# std             1.758355      0.485330           0.069485           0.325993
# ...

# %%
kamut_per_feature(data,x_axis='mort30', with_pie_aside=True, font_scale=1.3, figsize=(10, 5))

# %%
kamut_per_feature(data,x_axis='complication', with_pie_aside=True, font_scale=1.3, figsize=(10, 5))

# %%
ahuz_and_kamut_per_feature1_by_feature2(data,x_axis='month',feature='complication',count_what='Age',order_by_count=None, font_scale=1.5, side_by_side=True)

# %%
data['month'].dtype
# Out:
# dtype('O')

# %%
kamut_per_feature(data,'month',with_pie_aside=True , order_by_count=True , how_many_top_pie=None,figsize=(13, 6) , font_scale=1)

# %%
data['age_group'] = pd.qcut(data['Age'], q=20 , duplicates='drop')

# %%
ahuz_and_kamut_per_feature1_by_feature2(data,x_axis='age_group',feature='complication',count_what='Age',order_by_count=None, font_scale=1.5, side_by_side=True)

# %%
data.query('Age<10')
# Out:
#          bmi  Age  asa_status  baseline_cancer  baseline_charlson  \
# 14633  17.75  8.9           0                0                  1
# 14634  14.40  6.1           1                0                  1
#
#        baseline_cvd  baseline_dementia  baseline_diabetes  baseline_digestive  \
# 14633             0                  0                  0                   1
# 14634             0                  0                  0                   1
#
#        baseline_osteoart            ...              dow  gender  hour  month  \
# 14633                  0            ...                0       1  8.30      5
# 14634                  0            ...                2       0  7.65      4
#
#        moonphase  mort30  mortality_rsi  race  complication  \
# 14633          0       0           0.17     1             1
# 14634          1       0           1.06     0             1
#
#                        age_group
# 14633  (6.098999999999999, 35.1]
# 14634  (6.098999999999999, 35.1]
#
# ...

# %%
sns.heatmap(pd.DataFrame(data.corr()['complication'].reshape(25,1),index=data.corr()['complication'].index),annot=True)

# %%
sns.distplot(data[data['complication']==1]['mortality_rsi'], kde=True,hist=True ,kde_kws={"color": "r", "lw": 3, "label": "complicated"})
sns.distplot(data[data['complication']==0]['mortality_rsi'], kde=True , hist=True, kde_kws={"color": "b", "lw": 3, "label": "not complicated"})

# %%
sns.boxplot(y=data['mortality_rsi'],x=data['age_group'] ,hue=data['complication'])
