# %% [markdown]
# # Basics of Neural networks and other stuff
# ```In this exercise you will experience working with keras, a useful tool for designing and training neural networks.```
#
# ```~Ittai Haran```

# %% [markdown]
# ## Stage 1- predicting engineered functions
# ```Here you will design a simple fully connected network to predict a few simple functions. You will try different activation functions and different architectures (number of layers, size of layers).```

# %% [markdown]
# ```The first experiment will be guided:```
# - ```Read the first dataframe - function_1.csv.``` (in: https://drive.google.com/open?id=19Y9f2pkUwP7nrgbKCmCGHEomHmA0pwqx)
# - ```Plot y against x. can you guess the function y(x)?```
# - ```Split you data to train segment (70%) and test segment (30%).```
# - ```Write a fully connected neural network with one hidden layer with 3 units. I suggest using the``` [functional API](https://keras.io/getting-started/functional-api-guide/) - ```you can also find there examples for simple working with keras.```
# - ```Use tanh as an activation function for the hidden layer and a linear activation for the output layer.```
# - ```Use model.summary() to look at your model's architecture.```
# - ```Use mean squared error as the loss function and SGD (stochastic gradient descent) as the optimizer.```
# - ```Try training the network with different batch's sizes (don't be afraid to use many epochs- you don't have a lot of data).```
# - ```Plot y against x and f(x) against x on the same graph.```
# - ```Compute the loss on the test segment.```
# - ```Can you use a smaller hidden layer?```

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from keras.layers import Dense, Input
from keras.models import Model
import matplotlib.pyplot as plt
omport seaborn sns
# %matplotlib inline
# Out:
#   File "<ipython-input-4-655761971be1>", line 8
#     omport seaborn sns
#                  ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv('function_1.csv')

# %%
df.plot.scatter('x','y') # i guess the function is something like |x^2|

# %%
Y = df['y']
X = df['x']

# %%
train_X, test_X, train_Y, test_Y = train_test_split(X, Y, train_size =0.7 , test_size=0.3)

# %%
from keras import Model
from keras.layers import Dense, Input
from keras.optimizers import SGD
from keras.losses import binary_crossentropy

inp = Input((1,)) #we got only one feature

hidden = Dense(3, activation='tanh')(inp) #one hidden layer which contains 3 nuirons with tanh AF
out = Dense(1, activation='linear')(hidden)

model = Model(inp, out)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 1)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 6
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 4
# =================================================================
# Total params: 10
# Trainable params: 10
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=SGD(), loss='mean_squared_error', metrics=['accuracy'])

# %%
# scaler = StandardScaler()
# new_train_X = scaler.fit_transform(train_X)
# new_test_X = scaler.transform(test_X) 
# THE DATA IS ALREADY NORMALIZED #

model.fit(train_X, train_Y, batch_size=5, epochs=30, validation_data=(test_X, test_Y))
# Out:
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/30
# 7000/7000 [==============================] - 3s 393us/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 2/30
# 7000/7000 [==============================] - 3s 375us/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 3/30
# 7000/7000 [==============================] - 3s 370us/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 4/30
# 7000/7000 [==============================] - 3s 369us/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 5/30
# 7000/7000 [==============================] - 3s 369us/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 6/30
# 7000/7000 [==============================] - 3s 371us/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 7/30
# 7000/7000 [==============================] - 3s 366us/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 8/30
# 7000/7000 [==============================] - 3s 371us/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 9/30
# 7000/7000 [==============================] - 3s 366us/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 10/30
# 7000/7000 [==============================] - 3s 369us/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 11/30
# 7000/7000 [==============================] - 3s 370us/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 12/30
# 7000/7000 [==============================] - 3s 367us/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 13/30
# 7000/7000 [==============================] - 3s 374us/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 14/30
# 7000/7000 [==============================] - 3s 371us/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 15/30
# 7000/7000 [==============================] - 3s 371us/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 16/30
# 7000/7000 [==============================] - 3s 370us/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 17/30
# 7000/7000 [==============================] - 3s 370us/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 18/30
# 7000/7000 [==============================] - 3s 371us/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 19/30
# 7000/7000 [==============================] - 3s 374us/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 20/30
# 7000/7000 [==============================] - 3s 370us/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 21/30
# 7000/7000 [==============================] - 3s 373us/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 22/30
# 7000/7000 [==============================] - 3s 373us/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 23/30
# 7000/7000 [==============================] - 3s 369us/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 24/30
# 7000/7000 [==============================] - 3s 368us/step - loss: 9.8081e-04 - accuracy: 1.0000 - val_loss: 8.9448e-04 - val_accuracy: 1.0000
# Epoch 25/30
# 7000/7000 [==============================] - 3s 368us/step - loss: 8.3999e-04 - accuracy: 1.0000 - val_loss: 7.6837e-04 - val_accuracy: 1.0000
# Epoch 26/30
# 7000/7000 [==============================] - 3s 367us/step - loss: 7.1568e-04 - accuracy: 1.0000 - val_loss: 6.4653e-04 - val_accuracy: 1.0000
# Epoch 27/30
# 7000/7000 [==============================] - 3s 369us/step - loss: 6.0468e-04 - accuracy: 1.0000 - val_loss: 5.5082e-04 - val_accuracy: 1.0000
# Epoch 28/30
# 7000/7000 [==============================] - 3s 369us/step - loss: 5.0789e-04 - accuracy: 1.0000 - val_loss: 4.5859e-04 - val_accuracy: 1.0000
# Epoch 29/30
# 7000/7000 [==============================] - 3s 369us/step - loss: 4.2649e-04 - accuracy: 1.0000 - val_loss: 3.8054e-04 - val_accuracy: 1.0000
# Epoch 30/30
# 7000/7000 [==============================] - 3s 368us/step - loss: 3.5428e-04 - accuracy: 1.0000 - val_loss: 3.1738e-04 - val_accuracy: 1.0000

# %%
test_preds = model.predict(test_X)

# %%
df_helper = pd.DataFrame(test_X).reset_index(drop=True)
df_helper = df_helper.join(pd.DataFrame(test_preds , columns=['y_predicted_is_f(x)']).reset_index(drop=True)).join(pd.DataFrame(test_Y).reset_index(drop=True))

# %%
#!pip install seaborn --upgrade

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.scatterplot(x='x', y='y',
                     data=df_helper)

sns.scatterplot(x='x', y='y_predicted_is_f(x)',
                     data=df_helper)

# %%
mean_squared_error(test_Y , test_preds) #the loss
# Out:
# 0.00031737928370376736

# %%
#trying useing smaller hidden layer: containing only one nuiron.
from keras import Model
from keras.layers import Dense, Input
from keras.optimizers import SGD
from keras.losses import binary_crossentropy

inp = Input((1,)) #we got only one feature

hidden = Dense(1, activation='tanh')(inp) #one hidden layer which contains 3 nuirons with tanh AF
out = Dense(1, activation='linear')(hidden)

model = Model(inp, out)
model.summary()

model.compile(optimizer=SGD(), loss='mean_squared_error', metrics=['accuracy'])

model.fit(train_X, train_Y, batch_size=5, epochs=30, validation_data=(test_X, test_Y))
test_preds = model.predict(test_X)
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 1)                 0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 2
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/30
# 7000/7000 [==============================] - 2s 327us/step - loss: 0.0426 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 2/30
# 7000/7000 [==============================] - 2s 330us/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 3/30
# 7000/7000 [==============================] - 2s 331us/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 4/30
# 7000/7000 [==============================] - 2s 330us/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 5/30
# 7000/7000 [==============================] - 2s 328us/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 6/30
# 7000/7000 [==============================] - 2s 330us/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 7/30
# 7000/7000 [==============================] - 2s 328us/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 8/30
# 7000/7000 [==============================] - 2s 323us/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 9/30
# 7000/7000 [==============================] - 2s 326us/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 10/30
# 7000/7000 [==============================] - 2s 329us/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 11/30
# 7000/7000 [==============================] - 2s 329us/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 12/30
# 7000/7000 [==============================] - 2s 328us/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 9.1693e-04 - val_accuracy: 1.0000
# Epoch 13/30
# 7000/7000 [==============================] - 2s 327us/step - loss: 8.7046e-04 - accuracy: 1.0000 - val_loss: 7.9312e-04 - val_accuracy: 1.0000
# Epoch 14/30
# 7000/7000 [==============================] - 2s 332us/step - loss: 7.5022e-04 - accuracy: 1.0000 - val_loss: 6.8070e-04 - val_accuracy: 1.0000
# Epoch 15/30
# 7000/7000 [==============================] - 2s 330us/step - loss: 6.4775e-04 - accuracy: 1.0000 - val_loss: 6.0270e-04 - val_accuracy: 1.0000
# Epoch 16/30
# 7000/7000 [==============================] - 2s 330us/step - loss: 5.6182e-04 - accuracy: 1.0000 - val_loss: 5.1292e-04 - val_accuracy: 1.0000
# Epoch 17/30
# 7000/7000 [==============================] - 2s 330us/step - loss: 4.8780e-04 - accuracy: 1.0000 - val_loss: 4.4709e-04 - val_accuracy: 1.0000
# Epoch 18/30
# 7000/7000 [==============================] - 2s 327us/step - loss: 4.2497e-04 - accuracy: 1.0000 - val_loss: 3.9856e-04 - val_accuracy: 1.0000
# Epoch 19/30
# 7000/7000 [==============================] - 2s 331us/step - loss: 3.7085e-04 - accuracy: 1.0000 - val_loss: 3.5110e-04 - val_accuracy: 1.0000
# Epoch 20/30
# 7000/7000 [==============================] - 2s 327us/step - loss: 3.2473e-04 - accuracy: 1.0000 - val_loss: 2.9931e-04 - val_accuracy: 1.0000
# Epoch 21/30
# 7000/7000 [==============================] - 2s 330us/step - loss: 2.8450e-04 - accuracy: 1.0000 - val_loss: 2.6267e-04 - val_accuracy: 1.0000
# Epoch 22/30
# 7000/7000 [==============================] - 2s 324us/step - loss: 2.4946e-04 - accuracy: 1.0000 - val_loss: 2.3464e-04 - val_accuracy: 1.0000
# Epoch 23/30
# 7000/7000 [==============================] - 2s 332us/step - loss: 2.2043e-04 - accuracy: 1.0000 - val_loss: 2.0472e-04 - val_accuracy: 1.0000
# Epoch 24/30
# 7000/7000 [==============================] - 2s 328us/step - loss: 1.9477e-04 - accuracy: 1.0000 - val_loss: 1.8141e-04 - val_accuracy: 1.0000
# Epoch 25/30
# 7000/7000 [==============================] - 2s 329us/step - loss: 1.7221e-04 - accuracy: 1.0000 - val_loss: 1.6166e-04 - val_accuracy: 1.0000
# Epoch 26/30
# 7000/7000 [==============================] - 2s 328us/step - loss: 1.5289e-04 - accuracy: 1.0000 - val_loss: 1.4347e-04 - val_accuracy: 1.0000
# Epoch 27/30
# 7000/7000 [==============================] - 2s 329us/step - loss: 1.3635e-04 - accuracy: 1.0000 - val_loss: 1.2832e-04 - val_accuracy: 1.0000
# Epoch 28/30
# 7000/7000 [==============================] - 2s 335us/step - loss: 1.2156e-04 - accuracy: 1.0000 - val_loss: 1.1485e-04 - val_accuracy: 1.0000
# Epoch 29/30
# 7000/7000 [==============================] - 2s 329us/step - loss: 1.0892e-04 - accuracy: 1.0000 - val_loss: 1.0362e-04 - val_accuracy: 1.0000
# Epoch 30/30
# 7000/7000 [==============================] - 2s 330us/step - loss: 9.7888e-05 - accuracy: 1.0000 - val_loss: 9.3198e-05 - val_accuracy: 1.0000

# %%
df_helper = pd.DataFrame(test_X).reset_index(drop=True)
df_helper = df_helper.join(pd.DataFrame(test_preds , columns=['y_predicted_is_f(x)']).reset_index(drop=True)).join(pd.DataFrame(test_Y).reset_index(drop=True))

sns.scatterplot(x='x', y='y',
                     data=df_helper)

sns.scatterplot(x='x', y='y_predicted_is_f(x)',
                     data=df_helper)

# %%
mean_squared_error(test_Y , test_preds) #the loss - pretty good for that small nn
# Out:
# 9.319823503551794e-05

# %% [markdown]
# ```For the second experiment use the dataframe function_2.csv. Here you might need to have more layers. You might want to consider different``` [optimizers](https://keras.io/optimizers/), ```rather than SGD (for example, Adam).```
#
# (```function_2.csv can be found in:``` https://drive.google.com/open?id=1Fk32cP-4DSZ6v175UDVz_OChHE-dFLzq)

# %%
df_exp2 = pd.read_csv('function_2.csv')

# %%
#vizualize the data 
sns.set(rc={'figure.figsize':(7,7)})
sns.lineplot(x='x', y='y',data=df_exp2 )

# %%
X = df_exp2['x']
Y = df_exp2['y']
train_X, test_X, train_Y, test_Y = train_test_split(X, Y, train_size =0.7 , test_size=0.3)

# %%
from keras.models import Sequential

# define the keras model
model = Sequential()
model.add(Dense(20, input_dim=1, activation='linear'))
model.add(Dense(20, activation='tanh'))
model.add(Dense(3, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# compile the keras model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(train_X, train_Y, epochs=10, batch_size=5)
# Out:
# Epoch 1/10
# 7000/7000 [==============================] - 44s 6ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 2/10
# 7000/7000 [==============================] - 44s 6ms/step - loss: 7.1695e-04 - accuracy: 1.0000
# Epoch 3/10
# 7000/7000 [==============================] - 44s 6ms/step - loss: 1.7960e-04 - accuracy: 1.0000
# Epoch 4/10
# 7000/7000 [==============================] - 44s 6ms/step - loss: 1.0756e-04 - accuracy: 1.0000
# Epoch 5/10
# 7000/7000 [==============================] - 44s 6ms/step - loss: 8.9051e-05 - accuracy: 1.0000
# Epoch 6/10
# 7000/7000 [==============================] - 44s 6ms/step - loss: 5.9445e-05 - accuracy: 1.0000
# Epoch 7/10
# 7000/7000 [==============================] - 44s 6ms/step - loss: 2.5544e-05 - accuracy: 1.0000
# Epoch 8/10
# 7000/7000 [==============================] - 44s 6ms/step - loss: 2.4863e-05 - accuracy: 1.0000
# Epoch 9/10
# 7000/7000 [==============================] - 43s 6ms/step - loss: 2.1207e-05 - accuracy: 1.0000
# Epoch 10/10
# 7000/7000 [==============================] - 44s 6ms/step - loss: 1.9869e-05 - accuracy: 1.0000

# %%
test_preds = model.predict(test_X)

# %%
df_helper = pd.DataFrame(test_X).reset_index(drop=True)
df_helper = df_helper.join(pd.DataFrame(test_preds , columns=['y_predicted_is_f(x)']).reset_index(drop=True)).join(pd.DataFrame(test_Y).reset_index(drop=True))

sns.scatterplot(x='x', y='y',
                     data=df_helper)

sns.scatterplot(x='x', y='y_predicted_is_f(x)',
                     data=df_helper)

# %%
mean_squared_error(test_Y , test_preds)
# Out:
# 1.1008775614396533e-05

# %% [markdown]
# ```For the third experiment use the dataframe function_3.csv. Try different activation functions. How many layers you had to take?```
#
# (```function_3.csv can be found in:``` https://drive.google.com/open?id=1-XTfy6Wf0_WhEKJ9AnUGENBZRSNXkwNe)

# %%
import seaborn as sns
df_exp3 = pd.read_csv('function_3.csv')

# %%
#vizualize the data 
sns.set(rc={'figure.figsize':(7,7)})
sns.lineplot(x='x', y='y',data=df_exp3 )

# %%
X = df_exp3['x']
Y = df_exp3['y']
train_X, test_X, train_Y, test_Y = train_test_split(X, Y, train_size =0.7 , test_size=0.3)

# %%
from keras.models import Sequential

# define the keras model
model = Sequential()
#model.add(Dense(200, input_dim=1, activation='linear'))
model.add(Dense(30, input_dim=1, activation='linear'))
#model.add(Dense(100, activation='relu'))
#model.add(Dense(150, activation='linear'))
model.add(Dense(25, activation='tanh'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='linear'))
# compile the keras model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(train_X, train_Y, epochs=15, batch_size=15)
# Out:
# Epoch 1/15
# 70000/70000 [==============================] - 317s 5ms/step - loss: 0.4424 - accuracy: 1.0000
# Epoch 2/15
# 70000/70000 [==============================] - 325s 5ms/step - loss: 0.3796 - accuracy: 1.0000
# Epoch 3/15
# 70000/70000 [==============================] - 336s 5ms/step - loss: 0.3273 - accuracy: 1.0000
# Epoch 4/15
# 70000/70000 [==============================] - 339s 5ms/step - loss: 0.2942 - accuracy: 1.0000
# Epoch 5/15
# 70000/70000 [==============================] - 342s 5ms/step - loss: 0.2414 - accuracy: 1.0000
# Epoch 6/15
# 70000/70000 [==============================] - 342s 5ms/step - loss: 0.2018 - accuracy: 1.0000
# Epoch 7/15
# 70000/70000 [==============================] - 340s 5ms/step - loss: 0.1594 - accuracy: 1.0000
# Epoch 8/15
# 70000/70000 [==============================] - 341s 5ms/step - loss: 0.1437 - accuracy: 1.0000
# Epoch 9/15
# 70000/70000 [==============================] - 324s 5ms/step - loss: 0.1310 - accuracy: 1.0000
# Epoch 10/15
# 70000/70000 [==============================] - 331s 5ms/step - loss: 0.0428 - accuracy: 1.0000
# Epoch 11/15
# 70000/70000 [==============================] - 343s 5ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 12/15
# 70000/70000 [==============================] - 342s 5ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 13/15
# 70000/70000 [==============================] - 342s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 14/15
# 70000/70000 [==============================] - 342s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 15/15
# 70000/70000 [==============================] - 341s 5ms/step - loss: 0.0017 - accuracy: 1.0000

# %%
test_preds = model.predict(test_X)

df_helper = pd.DataFrame(test_X).reset_index(drop=True)
df_helper = df_helper.join(pd.DataFrame(test_preds , columns=['y_predicted_is_f(x)']).reset_index(drop=True)).join(pd.DataFrame(test_Y).reset_index(drop=True))

sns.scatterplot(x='x', y='y',
                     data=df_helper)

sns.scatterplot(x='x', y='y_predicted_is_f(x)',
                     data=df_helper)

# %% [markdown]
# ```As you maybe could've guessed, the function you fitted is``` $y = sin(x)$. ```Hence one might think it would be easy to fit a network with only one neuron, with activation of the sinus function. Try it: define a neural network with a single input and a single output, with no hidden layers, and use a sinus activation, to approximate function_3. Next we will understand why using sinus as an activation function is not a good idea.```
#
# ```You can use sin_activation provided below as the sinus activation: instead of writing activation='tanh' or activation='sigmoid', use activation=sin_activation.```

# %%
import keras.backend as K
def sin_activation(vec):
    return K.sin(vec)

# %%
from keras.models import Sequential
from keras.optimizers import Adam
LEARNING_RATE =0.25
# define the keras model
model = Sequential()
model.add(Dense(1, input_dim=1,activation=sin_activation))

# compile the keras model
model.compile(loss='mean_squared_error', optimizer=Adam(lr=LEARNING_RATE), metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(train_X, train_Y, epochs=3, batch_size=10)
# Out:
# Epoch 1/3
# 70000/70000 [==============================] - 12s 175us/step - loss: 0.2066 - accuracy: 1.0000
# Epoch 2/3
# 70000/70000 [==============================] - 12s 173us/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 3/3
# 70000/70000 [==============================] - 12s 173us/step - loss: 0.0069 - accuracy: 1.0000

# %%
test_preds = model.predict(test_X)

df_helper = pd.DataFrame(test_X).reset_index(drop=True)
df_helper = df_helper.join(pd.DataFrame(test_preds , columns=['y_predicted_is_f(x)']).reset_index(drop=True)).join(pd.DataFrame(test_Y).reset_index(drop=True))

sns.scatterplot(x='x', y='y',
                     data=df_helper)

sns.scatterplot(x='x', y='y_predicted_is_f(x)',
                     data=df_helper)

# %% [markdown]
# ```Let's explore the sinus activation. For this we will simplify the settings. We will generate 3 samples, with ```
# $x = [0, 0.5, 1]$ ``` and ``` $y=[sin(0), sin(0.5), sin(1)]$. ```We will keep using the simplest neural network, that has one input and one output, with no hidden layers. Hence the possible functions that the network can give us are functions of the form```
# <center>$y=sin(a\cdot x+b)$.<center>
#
# ```We can use the simple setting to compute and visualize the loss surface. As you recall, the loss is given by```
# <center>$\sum_i{(sin(a\cdot x_i+b)-y_i)^2}$<center>
#
# ```Create a matrix so that in the (i,j) entry there will be the loss for ``` $a = \frac{2\pi}{600}\cdot i$ and $b= \frac{2\pi}{600}\cdot j$. ```Visualize this matrix using plt.imshow.```

# %%
x = [0,0.5,1]
y = np.sin(x)

new_x = list(map(lambda x: x  * (2*np.pi)/600.0 , x))
new_y = list(map(lambda y: y  * (2*np.pi)/600.0 , y))

# %%
from keras.models import Sequential
from keras.optimizers import Adam
LEARNING_RATE =0.05
# define the keras model
model = Sequential()
model.add(Dense(1, input_dim=1,activation=sin_activation))

# compile the keras model
model.compile(loss='mean_squared_error', optimizer=Adam(lr=LEARNING_RATE), metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(x, y, epochs=30, batch_size=1 , verbose=0)

# %%
history = model.history.history['loss']
loss_his_sinus_original = pd.DataFrame(history)
sns.lineplot(x= loss_his_sinus_original.index , y=loss_his_sinus_original[0])
plt.title('X - num of epoch , Y - loss')
# Out:
# Text(0.5, 1.0, 'X - num of epoch , Y - loss')

# %%
# define the keras model
model = Sequential()
model.add(Dense(1, input_dim=1,activation=sin_activation))

# compile the keras model
model.compile(loss='mean_squared_error', optimizer=Adam(lr=LEARNING_RATE), metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(new_x, new_y, epochs=30, batch_size=1 , verbose=0)

# %%
history = model.history.history['loss']
loss_his_sinus_manipulate = pd.DataFrame(history)
sns.lineplot(x= loss_his_sinus_manipulate.index , y=loss_his_sinus_manipulate[0])
plt.title('X - num of epoch , Y - loss')
# Out:
# Text(0.5, 1.0, 'X - num of epoch , Y - loss')

# %% [markdown]
# ```Do the same for the beloved activation, tanh. Based on the images, what makes sinus a poor activation function and tanh a good activation function? answer in ``` $\underline{a\ cell\ below}$.

# %%
from keras.models import Sequential
from keras.optimizers import Adam
LEARNING_RATE =0.05
# define the keras model
model = Sequential()
model.add(Dense(1, input_dim=1,activation='tanh'))

# compile the keras model
model.compile(loss='mean_squared_error', optimizer=Adam(lr=LEARNING_RATE), metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(x, y, epochs=30, batch_size=1 , verbose=0)

# %%
history = model.history.history['loss']
loss_his_tanh_original = pd.DataFrame(history)
sns.lineplot(x= loss_his_tanh_original.index , y=loss_his_tanh_original[0])
plt.title('X - num of epoch , Y - loss')
# Out:
# Text(0.5, 1.0, 'X - num of epoch , Y - loss')

# %%
from keras.models import Sequential
from keras.optimizers import Adam
LEARNING_RATE =0.05
# define the keras model
model = Sequential()
model.add(Dense(1, input_dim=1,activation='tanh'))

# compile the keras model
model.compile(loss='mean_squared_error', optimizer=Adam(lr=LEARNING_RATE), metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(new_x, new_y, epochs=30, batch_size=1 , verbose=0)

# %%
history = model.history.history['loss']
loss_his_tanh_manipulate = pd.DataFrame(history)
sns.lineplot(x= loss_his_tanh_manipulate.index , y=loss_his_tanh_manipulate[0])
plt.title('X - num of epoch , Y - loss')
# Out:
# Text(0.5, 1.0, 'X - num of epoch , Y - loss')

# %%
#combine plots
sns.lineplot(x= loss_his_tanh_manipulate.index , y=loss_his_tanh_manipulate[0])
sns.lineplot(x= loss_his_sinus_manipulate.index , y=loss_his_sinus_manipulate[0])
plt.legend(['tanh' , 'sinus'])
plt.show()
sns.lineplot(x= loss_his_tanh_original.index , y=loss_his_tanh_original[0])
sns.lineplot(x= loss_his_sinus_original.index , y=loss_his_sinus_original[0])
plt.legend(['tanh' , 'sinus'])
plt.show()

# %%
#the tanh activition is more balanced and less affected by the scale change

# %% [markdown]
# ### Bonus:
# ```When training neural networks using keras we can use callback functions: There are functions that are called automatically during the training and can be of several usages. For example, we can use a callback function to save our model to a file upon the ending of an epoch.
# Below you will find a custom callback that keeps the weights for a and b in your sinus model. Use it like this:```
#
# ``` python
# wh = WeightsHistory()
# model.fit(X_train, Y_train, batch_size = 100, epochs = 10, verbose=2, callbacks=[wh])
# ```
#
# ```After you try training your model using the sinus activation you can plot the path your model took on the a-b plane. Add to your loss surface visualization a plot showing the a-b values during training.```
#
# ```Note: after using plt.imshow you got an image of the size``` $600\times 600$. ```You will have to scale your a-b path accordingly to see it on the same graph. Try zooming (by changing the scale of the image, enlarging the size of your image or using any other mean) to get a better view of the a-b path. Can you explain why didn't you get a convergence?```

# %%
from keras.callbacks import Callback
class WeightsHistory(Callback):
    def on_train_begin(self, logs={}):
        self.a_s = []
        self.b_s = []

    def on_batch_end(self, batch, logs={}):
        weights = self.model.get_weights()
        self.a_s.append(weights[0][0][0])
        self.b_s.append(weights[1][0])

# %%
LEARNING_RATE =0.05
# define the keras model
model = Sequential()
model.add(Dense(1, input_dim=1,activation=sin_activation))


# compile the keras model
model.compile(loss='mean_squared_error', optimizer=Adam(lr=LEARNING_RATE), metrics=['accuracy'])
# fit the keras model on the dataset

wh = WeightsHistory()
model.fit(x, y, epochs=30, batch_size=1 , verbose=0 , callbacks=[wh])

# %%
all_weights = pd.DataFrame(list(zip(wh.b_s , wh.a_s)) , columns=['b_s' , 'a_s'])

# %%
all_weights['epoch'] = pd.qcut(all_weights.index , 30 , labels=range(30))

# %%
loss_history = pd.DataFrame(model.history.history['loss'] , columns=['loss']).reset_index()

# %%
#model.history.history['loss']

# %%
all_weights_and_loss = all_weights.merge(loss_history , left_on='epoch' , right_on='index')

# %%
sns.scatterplot(x=all_weights_and_loss['epoch'] , y=all_weights_and_loss['b_s'])
sns.scatterplot(x=all_weights_and_loss['epoch'] , y=all_weights_and_loss['a_s'])
sns.scatterplot(x=all_weights_and_loss['epoch'] , y=all_weights_and_loss['loss'] , markers='x')
plt.legend(['b_s' , 'a_s' , 'loss'])

# %%
#the path  of the weights throw training:
sns.scatterplot(x=all_weights_and_loss['b_s'] , y=all_weights_and_loss['a_s'])

# %% [markdown]
# ## Stage 2- predict digits from MNIST
# ```Use your knowledge to create a good prediction for the MNIST dataset. Note that this a classification problem, and you will have to use a different loss: for example, the binary cross entropy (log loss). Furthermore, you might want to use softmax to generate predictions. You can use activation='softmax' in the last layer of your network.
# good luck!```

# %%
from keras.datasets import mnist
(X_train_images, Y_train_num), (X_test_images, Y_test_num) = mnist.load_data()
plt.imshow(X_train_images[0])
plt.show()

X_train = X_train_images.reshape(-1,784)
X_test = X_test_images.reshape(-1,784)
Y_train = pd.get_dummies(Y_train_num)
Y_test = pd.get_dummies(Y_test_num)

# %%
len(X_train[0])
# Out:
# 784

# %%
train_X
# Out:
# array([0.82974535, 0.46399438, 0.63494993, ..., 0.02246137, 0.46563859,
#        0.86003705])

# %%
from keras.models import Sequential
from keras.losses import logcosh, binary_crossentropy
from keras.optimizers import Adam, Nadam, RMSprop , SGD
LEARNING_RATE =0.1
# define the keras model
model = Sequential()
#model.add(Dense(200, input_dim=1, activation='linear'))
model.add(Dense(64, input_dim=784, activation='relu'))
model.add(Dense(64, input_dim=784, activation='relu'))
model.add(Dense(64, input_dim=784, activation='relu'))
#model.add(Dense(64, input_dim=784, activation='relu'))
model.add(Dense(16, input_dim=784, activation='relu'))
# model.add(Dense(350, activation='tanh'))
# model.add(Dense(180, activation='relu'))
# model.add(Dense(50, input_dim=784, activation='tanh'))
model.add(Dense(10, activation='softmax'))
# compile the keras model
model.compile(loss=binary_crossentropy, optimizer=SGD(), metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(X_train, Y_train, epochs=10, batch_size=15)
# Out:
# Epoch 1/10
# 60000/60000 [==============================] - 385s 6ms/step - loss: 0.2482 - accuracy: 0.9265
# Epoch 2/10
# 60000/60000 [==============================] - 388s 6ms/step - loss: 0.2083 - accuracy: 0.9343
# Epoch 3/10
# 60000/60000 [==============================] - 389s 6ms/step - loss: 0.1968 - accuracy: 0.9360
# Epoch 4/10
# 60000/60000 [==============================] - 393s 7ms/step - loss: 0.1825 - accuracy: 0.9382
# Epoch 5/10
# 60000/60000 [==============================] - 390s 6ms/step - loss: 0.1518 - accuracy: 0.9443
# Epoch 6/10
# 60000/60000 [==============================] - 390s 6ms/step - loss: 0.1007 - accuracy: 0.9642
# Epoch 7/10
# 60000/60000 [==============================] - 388s 6ms/step - loss: 0.0647 - accuracy: 0.9778
# Epoch 8/10
# 60000/60000 [==============================] - 389s 6ms/step - loss: 0.0389 - accuracy: 0.9882
# Epoch 9/10
# 60000/60000 [==============================] - 390s 7ms/step - loss: 0.0315 - accuracy: 0.9903
# Epoch 10/10
# 60000/60000 [==============================] - 391s 7ms/step - loss: 0.0277 - accuracy: 0.9915

# %%
preds = model.predict(X_test)
test_predictions = model.predict_classes(X_test)
Y_test['true_label'] = Y_test.apply(lambda x: x[x>0].index[0] , axis=1)

# %%
from sklearn.metrics import confusion_matrix

confusion = confusion_matrix(Y_test['true_label'],test_predictions)
print(confusion)
# Out:
# [[ 958    0    3    0    2    7    8    1    1    0]
#  [   1 1115    4    5    0    0    5    0    5    0]
#  [   8    2  961    3    6    0    6    9   35    2]
#  [   1    0    7  970    0    3    2    4   15    8]
#  [   2    3    7    2  914    0   13    2    3   36]
#  [   4    0    0   52    2  799    7    3   17    8]
#  [   7    3    0    2    9    4  928    0    4    1]
#  [   1    6   15   11    7    1    0  966    9   12]
#  [   3    2   12   23    2    8    4    6  900   14]
#  [   3    4    2   25   21    4    2    5    7  936]]

# %%
from sklearn.metrics import precision_recall_fscore_support as score


precision, recall, fscore, support = score(Y_test['true_label'],test_predictions)

print('precision: {}'.format(precision))
print('recall: {}'.format(recall))
print('fscore: {}'.format(fscore))
print('support: {}'.format(support))
# Out:
# precision: [0.96963563 0.98237885 0.95054402 0.88746569 0.94911734 0.96731235
#  0.95179487 0.96987952 0.90361446 0.92035398]
# recall: [0.97755102 0.98237885 0.93120155 0.96039604 0.93075356 0.89573991
#  0.96868476 0.93968872 0.92402464 0.92765114]
# fscore: [0.97357724 0.98237885 0.94077337 0.92249168 0.93984576 0.93015134
#  0.96016555 0.95454545 0.91370558 0.92398815]
# support: [ 980 1135 1032 1010  982  892  958 1028  974 1009]

# %% [markdown]
# ## Stage 3 - exploring deep neural networks
# ```In this part we will explore the problems with training deep networks.```

# %% [markdown]
# ```We will work with the simplest data possible and will try to approximate the identity function, with one feature.
# Generate 10,000 samples using np.random.random and have ``` $y=x$. ```Create a neural network with a single hidden layer with 3 neurons in it and sigmoid activation. Approximate the identity function.```

# %%
x = np.random.random(10000)
y = x.copy()

train_X, test_X, train_Y, test_Y = train_test_split(x, y, train_size =0.7 , test_size=0.3)

# %%
LEARNING_RATE =0.05
# define the keras model
model = Sequential()
model.add(Dense(3, input_dim=1,activation='sigmoid'))
model.add(Dense(1, input_dim=1,activation='linear'))

# compile the keras model
model.compile(loss='mean_squared_error', optimizer=Adam(lr=LEARNING_RATE), metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(train_X, train_Y, epochs=10, batch_size=10)
# Out:
# Epoch 1/10
# 7000/7000 [==============================] - 2s 292us/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 2/10
# 7000/7000 [==============================] - 2s 290us/step - loss: 3.3237e-05 - accuracy: 1.0000
# Epoch 3/10
# 7000/7000 [==============================] - 2s 287us/step - loss: 3.9249e-05 - accuracy: 1.0000
# Epoch 4/10
# 7000/7000 [==============================] - 2s 289us/step - loss: 3.5295e-05 - accuracy: 1.0000
# Epoch 5/10
# 7000/7000 [==============================] - 2s 292us/step - loss: 2.2089e-05 - accuracy: 1.0000
# Epoch 6/10
# 7000/7000 [==============================] - 2s 292us/step - loss: 1.8459e-05 - accuracy: 1.0000
# Epoch 7/10
# 7000/7000 [==============================] - 2s 294us/step - loss: 2.0143e-05 - accuracy: 1.0000
# Epoch 8/10
# 7000/7000 [==============================] - 2s 289us/step - loss: 8.1584e-06 - accuracy: 1.0000
# Epoch 9/10
# 7000/7000 [==============================] - 2s 292us/step - loss: 2.0809e-05 - accuracy: 1.0000
# Epoch 10/10
# 7000/7000 [==============================] - 2s 291us/step - loss: 1.2656e-05 - accuracy: 1.0000

# %%
preds = model.predict(test_X)

# %%
mean_squared_error(test_Y , preds)
# Out:
# 3.2621912114438087e-06

# %% [markdown]
# ```Add 50 hidden layers to your network, again, with 3 neurons in each layer and sigmoid activatoin. Try approximating the identity function using this network.```

# %%
# define the keras model
from keras.layers import  RepeatVector
model = Sequential()
model.add(Dense(3, input_dim=1,activation='sigmoid'))
for i in range(50):
    model.add(Dense(3 ,activation='sigmoid'))

model.add(Dense(1 ,activation='linear'))

# compile the keras model
model.compile(loss='mean_squared_error', optimizer=SGD(), metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(train_X, train_Y, epochs=10, batch_size=10)
# Out:
# Epoch 1/10
# 7000/7000 [==============================] - 25s 4ms/step - loss: 0.0983 - accuracy: 1.0000
# Epoch 2/10
# 7000/7000 [==============================] - 25s 4ms/step - loss: 0.0835 - accuracy: 1.0000
# Epoch 3/10
# 7000/7000 [==============================] - 25s 4ms/step - loss: 0.0835 - accuracy: 1.0000
# Epoch 4/10
# 7000/7000 [==============================] - 25s 4ms/step - loss: 0.0835 - accuracy: 1.0000
# Epoch 5/10
# 7000/7000 [==============================] - 25s 4ms/step - loss: 0.0835 - accuracy: 1.0000
# Epoch 6/10
# 7000/7000 [==============================] - 25s 4ms/step - loss: 0.0835 - accuracy: 1.0000
# Epoch 7/10
# 7000/7000 [==============================] - 25s 4ms/step - loss: 0.0834 - accuracy: 1.0000
# Epoch 8/10
# 7000/7000 [==============================] - 25s 4ms/step - loss: 0.0835 - accuracy: 1.0000
# Epoch 9/10
# 7000/7000 [==============================] - 25s 4ms/step - loss: 0.0834 - accuracy: 1.0000
# Epoch 10/10
# 7000/7000 [==============================] - 25s 4ms/step - loss: 0.0835 - accuracy: 1.0000

# %% [markdown]
# ```Why isn't it working? Explain it in ``` $\underline{a\ cell\ below}$. ```In your explanation regard the process of back propagation and the formula of gradients found in the first layers of the network. Regard also the possible values of the derivative of the sigmoid function.```

# %%
#If the sigmoid functions gives a HIGH or LOW value(Pretty good confidence),
#the derivative of that value is LOW. If you get a value at the steepest slope(0.5),
#the derivative of that value is HIGH -> and high value will change the original value and therefore will not be identity to the original value thats why approximating the identity function using this network is not possible.
#in the back propagation process there will be no big changes if there are some bad predictions beacuse the use of the derivatives is negligible.

# %% [markdown]
# ```Run the cell below. In weight_grads you will have a list of the gradients computed in every layer. For each layer take the maximum absolute value of the gradients. Plot a graph of the maximum values against the number of layer. Also plot it in logarithmic scale. Use it to justify your answer from before in ``` $\underline{a\ cell\ below}$.

# %%
import numpy as np
from keras import backend as K

def get_weight_grad(model, inputs, outputs):
    """ Gets gradient of model for given inputs and outputs for all weights"""
    grads = model.optimizer.get_gradients(model.total_loss, model.trainable_weights)
    symb_inputs = (model._feed_inputs + model._feed_targets + model._feed_sample_weights)
    f = K.function(symb_inputs, grads)
    x, y, sample_weight = model._standardize_user_data(inputs, outputs)
    output_grad = f(x + y + sample_weight)
    return output_grad

weight_grads = get_weight_grad(model, train_X, train_Y)

# %%
def max_weights(arr):
    return abs(np.amax(arr))
    
max_grad = list(map(max_weights , weight_grads))

# %%
grad_df = pd.DataFrame(max_grad , columns=['absolute_max_grad'])

# %%
grad_df['log'] = np.log(grad_df['absolute_max_grad'])

# %%
sns.scatterplot(x=grad_df.index , y = grad_df['absolute_max_grad'])

# %%
sns.scatterplot(x=grad_df.index , y = grad_df['log'])
