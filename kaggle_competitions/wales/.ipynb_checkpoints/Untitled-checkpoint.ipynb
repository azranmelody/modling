# %%
import pandas as pd
import numpy as np
import os

from matplotlib import image
import matplotlib.pyplot as plt
import cv2
import keras

from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
from img_preprocess import imges_load as loader
from img_preprocess import reshaper
from img_preprocess import preprocess

# %%
data = pd.read_csv('train.csv')

# %%
data['Id'].value_counts()
# Out:
# new_whale    9664
# w_23a388d      73
# w_9b5109b      65
# w_9c506f6      62
# w_0369a5c      61
#              ...
# w_51a60f0       1
# w_ae09e99       1
# w_2497490       1
# w_122eec1       1
# w_8daccba       1
# Name: Id, Length: 5005, dtype: int64

# %%
wales_path = "D:/Download/humpback-whale-identification/train"
images = loader.load_several_imgs(wales_path,30)

# %%
images[0].shape
# Out:
# (700, 1050, 3)

# %%
reshaped_images_avg = reshaper.reshape_to_avg(images.copy())
reshaped_images_const = reshaper.reshape_to_constant(images.copy(),100,100)

# %%
for i in range(2):
    plt.figure(figsize=(5,5))
    plt.imshow(reshaped_images_const[i])
    plt.show()

# %%
reshaped_images_const[0].shape
# Out:
# (100, 100, 3)

# %%
#scale the data
reshaped_images_const_normalized = preprocess.scale_data(reshaped_images_const,255.0)

# %%
Y_train_dum, label_encoder = preprocess.prepare_labels_string_to_onehot(data, 'Id')
